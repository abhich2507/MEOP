# %%
import sys
import os

# ROOT is now automatically configured via sitecustomize.py
import ROOT
from ROOT import TCanvas, TFile, TPaveText, TGraph
from ROOT import gROOT

print(f"✓ ROOT version: {ROOT.gROOT.GetVersion()}")
print(f"✓ ROOTSYS: {os.environ.get('ROOTSYS', 'Not set')}")
# Out:
# ✓ ROOT version: 6.36.06
# ✓ ROOTSYS: /opt/homebrew/Cellar/root/6.36.06

# %%
c1=TCanvas("c1","Polarization vs time",800,600)
c1.SetGridx()
c1.SetGridy()

# %%
file=ROOT.RDF.FromCSV("/Users/snip/Documents/MEOP/20G_datagrab1.csv")
file.Display().Print()
# Out:
# +-----+---------------------------------------------+---------------------------------+-----+
# | Row | Polarization (%) - Voltage (Formula Result) | Time - Voltage (Formula Result) | ... |
# +-----+---------------------------------------------+---------------------------------+-----+
# | 0   | 0.651393                                    | "06:38.7"                       | ... |
# +-----+---------------------------------------------+---------------------------------+-----+
# | 1   | 0.711816                                    | "06:39.7"                       | ... |
# +-----+---------------------------------------------+---------------------------------+-----+
# | 2   | 0.612180                                    | "06:40.8"                       | ... |
# +-----+---------------------------------------------+---------------------------------+-----+
# | 3   | 0.570962                                    | "06:41.8"                       | ... |
# ...
